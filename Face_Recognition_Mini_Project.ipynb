# %% [markdown]
# <a href="https://colab.research.google.com/github/N2000-hack/Face_Detection/blob/main/Face_Recognition_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Images for GITHUB

# %%
# !git clone https://github.com/N2000-hack/Face_Detection.git
# %cd Face_Detection
# Out:
# Cloning into 'Face_Detection'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 89 (delta 13), reused 21 (delta 6), pack-reused 0
# Unpacking objects: 100% (89/89), done.
# /content/Face_Detection/Face_Detection

# %% [markdown]
# Installing face_recognition library

# %%
# !pip install face_recognition

# %% [markdown]
# Training the Model with Images in GITHUB

# %%
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display
from google.colab.patches import cv2_imshow
import cv2
from datetime import datetime

face_1 = face_recognition.load_image_file("18071A12C1 (1).jpeg")
face_1_encoding = face_recognition.face_encodings(face_1)[0]

face_2 = face_recognition.load_image_file("18071A12C2 (5).jpeg")
face_2_encoding = face_recognition.face_encodings(face_2)[0]

face_3 = face_recognition.load_image_file("18071A12E0 (2).jpeg")
face_3_encoding = face_recognition.face_encodings(face_3)[0]

face_4 = face_recognition.load_image_file("18071A12E3 (5).jpeg")
face_4_encoding = face_recognition.face_encodings(face_4)[0]

face_5 = face_recognition.load_image_file("18071A12E4 (5).jpeg")
face_5_encoding = face_recognition.face_encodings(face_5)[0]

face_6 = face_recognition.load_image_file("18071A12E9 (1).jpeg")
face_6_encoding = face_recognition.face_encodings(face_6)[0]

face_7 = face_recognition.load_image_file("18071A12F0 (2).jpeg")
face_7_encoding = face_recognition.face_encodings(face_7)[0]

face_8 = face_recognition.load_image_file("18071A12F6 (5).jpeg")
face_8_encoding = face_recognition.face_encodings(face_8)[0]

face_9 = face_recognition.load_image_file("18071A12F7 (6).jpeg")
face_9_encoding = face_recognition.face_encodings(face_9)[0]

face_10 = face_recognition.load_image_file("18071A12F8 (1).jpeg")
face_10_encoding = face_recognition.face_encodings(face_10)[0]

face_11 = face_recognition.load_image_file("18071A12F9 (5).jpeg")
face_11_encoding = face_recognition.face_encodings(face_11)[0]

face_12 = face_recognition.load_image_file("18071A12G0 (5).jpeg")
face_12_encoding = face_recognition.face_encodings(face_12)[0]

face_13 = face_recognition.load_image_file("18071A12G1 (2).jpeg")
face_13_encoding = face_recognition.face_encodings(face_13)[0]

face_14 = face_recognition.load_image_file("18071A12G2 (2).jpeg")
face_14_encoding = face_recognition.face_encodings(face_14)[0]

face_15 = face_recognition.load_image_file("18071A12G3 (5).jpeg")
face_15_encoding = face_recognition.face_encodings(face_15)[0]

face_16 = face_recognition.load_image_file("18071A12G4 (6).jpeg")
face_16_encoding = face_recognition.face_encodings(face_16)[0]

face_17 = face_recognition.load_image_file("18071A12G6 (5).jpeg")
face_17_encoding = face_recognition.face_encodings(face_17)[0]

face_18 = face_recognition.load_image_file("18071A12G7 (1).jpeg")
face_18_encoding = face_recognition.face_encodings(face_18)[0]

face_19 = face_recognition.load_image_file("18071A12G8 (4).jpeg")
face_19_encoding = face_recognition.face_encodings(face_19)[0]

face_20 = face_recognition.load_image_file("18071A12G9 (6).jpeg")
face_20_encoding = face_recognition.face_encodings(face_20)[0]

face_21 = face_recognition.load_image_file("18071A12H0 (1).jpeg")
face_21_encoding = face_recognition.face_encodings(face_21)[0]

face_22 = face_recognition.load_image_file("18071A12H1 (2).jpeg")
face_22_encoding = face_recognition.face_encodings(face_22)[0]

face_23 = face_recognition.load_image_file("18071A12H2 (4).jpeg")
face_23_encoding = face_recognition.face_encodings(face_23)[0]

face_24 = face_recognition.load_image_file("18071A12H3 (5).jpeg")
face_24_encoding = face_recognition.face_encodings(face_24)[0]

face_25 = face_recognition.load_image_file("18071A12H4 (1).jpeg")
face_25_encoding = face_recognition.face_encodings(face_25)[0]

face_26 = face_recognition.load_image_file("18071A12H5 (2).jpeg")
face_26_encoding = face_recognition.face_encodings(face_26)[0]

face_27 = face_recognition.load_image_file("18071A12H6 (5).jpeg")
face_27_encoding = face_recognition.face_encodings(face_27)[0]

face_28 = face_recognition.load_image_file("18071A12H7 (4).jpeg")
face_28_encoding = face_recognition.face_encodings(face_28)[0]

face_29 = face_recognition.load_image_file("18071A12H8 (5).jpeg")
face_29_encoding = face_recognition.face_encodings(face_29)[0]

face_30 = face_recognition.load_image_file("19075A1213 (4).jpeg")
face_30_encoding = face_recognition.face_encodings(face_30)[0]

known_face_encodings = [
    face_1_encoding,
    face_2_encoding,
    face_3_encoding,
    face_4_encoding,
    face_5_encoding,
    face_6_encoding,
    face_7_encoding,
    face_8_encoding,
    face_9_encoding,
    face_10_encoding,
    face_11_encoding,
    face_12_encoding,
    face_13_encoding,
    face_14_encoding,
    face_15_encoding,
    face_16_encoding,
    face_17_encoding,
    face_18_encoding,
    face_19_encoding,
    face_20_encoding,
    face_21_encoding,
    face_22_encoding,
    face_23_encoding,
    face_24_encoding,
    face_25_encoding,
    face_26_encoding,
    face_27_encoding,
    face_28_encoding,
    face_29_encoding,
    face_30_encoding


]
known_face_names = [
    "C1",
    "C2",
    "E0",
    "E3",
    "E4",
    "E9",
    "F0",
    "F6",
    "F7",
    "F8",
    "F9",
    "G0",
    "G1",
    "G2",
    "G3",
    "G4",
    "G6",
    "G7",
    "G8",
    "G9",
    "H0",
    "H1",
    "H2",
    "H3",
    "H4",
    "H5",
    "H6",
    "H7",
    "H8",
    "LE13",
]
print("Done learning and creating profiles")
# Out:
# Done learning and creating profiles

# %% [markdown]
# Entering the attendance into Attendance.csv

# %%
def makeAttendanceEntry(name):
    with open('Attendance.csv','r+') as FILE:
        allLines = FILE.readlines()
        attendanceList = []
        for line in allLines:
            entry = line.split(',')
            attendanceList.append(entry[0])
        if name not in attendanceList:
            now = datetime.now()
            dtString = now.strftime('%d/%b/%Y, %H:%M:%S')
            FILE.writelines(f'\n{name},{dtString}')

# %% [markdown]
# Capturing a live Image to Recognize

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %% [markdown]
# Recognizing the Live Captured Image

# %%
#file_name = "unknown_e9.jpeg"
#file_name = "unknow_g3.jpeg"
file_name = "Unknown_h7.jpeg"

unknown_image = face_recognition.load_image_file(file_name)
unknown_image_to_draw = cv2.imread(file_name)

face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

pil_image = Image.fromarray(unknown_image)
draw = ImageDraw.Draw(pil_image)

for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # See if the face is a match for the known face(s)
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

    name = "Unknown"

    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]

    # Draw a box around the face using the Pillow module
    cv2.rectangle(unknown_image_to_draw,(left, top), (right, bottom), (0,255,0),3 )
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 255, 255))
    cv2.putText(unknown_image_to_draw,name,(left,top-20), cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2,cv2.LINE_AA)
    print(name)
    makeAttendanceEntry(name)
    

# display(pil_image)
cv2_imshow(unknown_image_to_draw)
# Out:
# H7
# <PIL.Image.Image image mode=RGB size=609x1024 at 0x7F527B5ADF10>
